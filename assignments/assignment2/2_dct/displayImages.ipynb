# %%
from PIL import Image
im = Image.open('image.tif')
im
# Out:
# <PIL.TiffImagePlugin.TiffImageFile image mode=RGB size=640x480 at 0xB099D8C8>

# %%
im = Image.open('original_color.tif')
im
# Out:
# <PIL.TiffImagePlugin.TiffImageFile image mode=L size=640x480 at 0xB36D23B8>

# %%
im = Image.open('opencv_dct.tif')
im
# Out:
# <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0xB36D2A60>

# %%
im = Image.open('dct_lab_naive.tif')
im
# Out:
# <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0xB36D2B20>

# %%
im = Image.open('dct_lab_opt.tif')
im
# Out:
# <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0xB36CB7A8>

# %%
im = Image.open('labDctTimeResults.jpg')
im
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=597x408 at 0xB0934508>
