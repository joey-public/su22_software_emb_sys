# %%
from PIL import Image
im = Image.open('frame.tif')
im
# Out:
# <PIL.TiffImagePlugin.TiffImageFile image mode=RGB size=640x480 at 0xB08A4190>

# %%
im = Image.open('frame_gray.tif')
im
# Out:
# <PIL.TiffImagePlugin.TiffImageFile image mode=L size=640x480 at 0xB08A4658>

# %%
im = Image.open('dct_input.tif')
im
# Out:
# <PIL.TiffImagePlugin.TiffImageFile image mode=L size=16x16 at 0xB08A4388>

# %%
im = Image.open('dct_org.tif')
im
# Out:
# <PIL.TiffImagePlugin.TiffImageFile image mode=L size=16x16 at 0xB089ACE8>

# %%
im = Image.open('dct_student.tif')
im
# Out:
# <PIL.TiffImagePlugin.TiffImageFile image mode=L size=16x16 at 0xB0897250>

# %%
im = Image.open('myInv.tif')
im
# Out:
# <PIL.TiffImagePlugin.TiffImageFile image mode=L size=16x16 at 0xB089AD90>
